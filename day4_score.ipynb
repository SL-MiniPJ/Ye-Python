# %%
# 성적처리 program  # 등록, 검색, 삭제, 수정, 조회, 파일 입출력
import pickle

#과목 설정
subject=['국어','영어','수학','과학']

def read(menu):
    program = dict()
    with open('score2/program.p','rb') as file:
        program=pickle.load(file)
        if menu==5:
            for key, value in program.items():
                print(key,':', value)
    return program
    
def write():
    with open('score2/program.p','wb') as file:
        pickle.dump(program,file)
    return program

def inputs(name):
    scores = {subject[i]:input(subject[i]+' : ') for i in range(len(subject))}
    program.setdefault(name,scores)

def select(name):
    if program.get(name) !=None :
        print(name,'성적')
        print(program.get(name))
    else:
        print('존재하지 않는 학생입니다.')
        
def delete(name,menu):
    if program.get(name) !=None :
        program.pop(name)
        if menu==3:
            print('삭제 되었습니다.')
        elif menu==4:
            inputs(name)
            print('수정 되었습니다.')
    else:
        print('존재하지 않는 학생입니다.')


while True:
    menu=int(input('\n1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료\n'))

    if menu==1: # 등록
        print('등록하기')
        name=input('이름 : ')
        read(menu)
        inputs(name)
        write()

    if menu==2: # 검색
        print('검색하기')
        name=input('이름 : ')
        read(menu)
        select(name)

    if menu==3: # 삭제
        print('삭제하기')
        name=input('이름 : ')
        read(menu)
        delete(name,menu)
        write()

    if menu==4: # 수정
        print('수정하기')
        name=input('이름 : ')
        read(menu)
        delete(name,menu)
        write()

    if menu==5: # 전체 조회
        print('전체 조회')
        read(menu)            
    
    if menu==6: # 종료
        print('종료되었습니다.')
        break
# Out:
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 5
# 전체 조회
# test1 : {'국어': '10', '영어': '20', '수학': '30', '과학': '40'}
# test2 : {'국어': '20', '영어': '30', '수학': '40', '과학': '50'}
# test6 : {'국어': '10', '영어': '20', '수학': '30', '과학': '40'}
# test3 : {'국어': '1', '영어': '1', '수학': '1', '과학': '1'}
# test4 : {'국어': '11', '영어': '22', '수학': '33', '과학': '44'}
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 1
# 등록하기
# 이름 : test5
# 국어 : 55
# 영어 : 66
# 수학 : 77
# 과학 : 88
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 2
# 검색하기
# 이름 : test2
# test2 성적
# {'국어': '20', '영어': '30', '수학': '40', '과학': '50'}
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 3
# 삭제하기
# 이름 : test6
# 삭제 되었습니다.
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 3
# 삭제하기
# 이름 : test6
# 존재하지 않는 학생입니다.
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 4
# 수정하기
# 이름 : test3
# 국어 : 12
# 영어 : 23
# 수학 : 34
# 과학 : 45
# 수정 되었습니다.
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 4
# 수정하기
# 이름 : test6
# 존재하지 않는 학생입니다.
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 5
# 전체 조회
# test1 : {'국어': '10', '영어': '20', '수학': '30', '과학': '40'}
# test2 : {'국어': '20', '영어': '30', '수학': '40', '과학': '50'}
# test4 : {'국어': '11', '영어': '22', '수학': '33', '과학': '44'}
# test5 : {'국어': '55', '영어': '66', '수학': '77', '과학': '88'}
# test3 : {'국어': '12', '영어': '23', '수학': '34', '과학': '45'}
#
# 1.등록 | 2.검색 | 3.삭제 | 4.수정 | 5.전체 조회 | 6.종료
# 6
# 종료되었습니다.
